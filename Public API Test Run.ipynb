# %%
#Set up API 
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd57ef7c5-1b2c-4bb4-bddb-cd40a81d25a8',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-08-28T04:55:52.809Z', 'error_code': 0, 'error_message': None, 'elapsed': 71, 'credit_count': 1, 'notice': None, 'total_count': 9980}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11651, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.json_normalize(data['status'])
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2024-08-28T04:55:52.809Z           0          None       71             1
#
#   notice  total_count
# 0   None         9980

# %%
#df = pd.json_normalize(data['data'])
#df['timestamp'] = pd.to_datetime('now')
#df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11651
# 1    1027     Ethereum    ETH      ethereum              9249
# 2     825  Tether USDt   USDT        tether             95668
# 3    1839          BNB    BNB           bnb              2220
# 4    5426       Solana    SOL        solana               722
# 5    3408         USDC   USDC      usd-coin             21697
# 6      52          XRP    XRP           xrp              1372
# 7      74     Dogecoin   DOGE      dogecoin              1047
# 8    1958         TRON    TRX          tron              1018
# 9   11419      Toncoin    TON       toncoin               536
# 10   2010      Cardano    ADA       cardano              1234
# 11   5805    Avalanche   AVAX     avalanche               768
# 12   5994    Shiba Inu   SHIB     shiba-inu               862
# 13   1975    Chainlink   LINK     chainlink              1833
# ...

# %%
# Making it automated

def api_runner():
    global df
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': 'd57ef7c5-1b2c-4bb4-bddb-cd40a81d25a8',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df 

    if not os.path.isfile(r'C:\Users\User\Documents\New_lyfe\Pytan\API_datasets.csv'):
        df.to_csv(r'C:\Users\User\Documents\New_lyfe\Pytan\API_datasets.csv', header = 'column_names')
    else:
        df.to_csv(r'C:\Users\User\Documents\New_lyfe\Pytan\API_datasets.csv', mode = 'a', header = False)

# mode a = append

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('Task successfully completed API Runner')
    sleep(60) #sleep for 1 min
exit()
# Out:
# Task successfully completed API Runner
# Task successfully completed API Runner
# Task successfully completed API Runner
# Task successfully completed API Runner
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 8
#       6     api_runner()
#       7     print('Task successfully completed API Runner')
# ----> 8     sleep(60) #sleep for 1 min
#       9 exit()
#
# KeyboardInterrupt:

# %%
df76 = pd.read_csv(r'C:\Users\User\Documents\New_lyfe\Pytan\API_datasets.csv')
df76
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             11651
# 1            1   1027     Ethereum    ETH      ethereum              9250
# 2            2    825  Tether USDt   USDT        tether             95688
# 3            3   1839          BNB    BNB           bnb              2220
# 4            4   5426       Solana    SOL        solana               722
# 5            5   3408         USDC   USDC      usd-coin             21697
# 6            6     52          XRP    XRP           xrp              1372
# 7            7     74     Dogecoin   DOGE      dogecoin              1047
# 8            8   1958         TRON    TRX          tron              1018
# 9            9  11419      Toncoin    TON       toncoin               536
# 10          10   2010      Cardano    ADA       cardano              1234
# 11          11   5805    Avalanche   AVAX     avalanche               768
# ...
